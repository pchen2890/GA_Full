# %% [markdown]
# ### Intro to Pandas 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read in csv file and create a pandas dataframe

df = pd.read_csv('sales.csv')

# %%
# head of dataset

df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %%
# tail of dataset

df.tail()
# Out:
#     Account                         Name          Rep        Manager  \
# 12   239344                   Stokes LLC  Cedric Moss  Fred Anderson
# 13   307599  Kassulke, Ondricka and Metz   Wendy Yule  Fred Anderson
# 14   688981                  Keeling LLC   Wendy Yule  Fred Anderson
# 15   729833                    Koepp Ltd   Wendy Yule  Fred Anderson
# 16   729833                    Koepp Ltd   Wendy Yule  Fred Anderson
#
#         Product  Quantity   Price     Status
# 12     Software         1   10000  presented
# 13  Maintenance         3    7000        won
# 14          CPU         5  100000        won
# 15          CPU         2   65000   declined
# 16      Monitor         2    5000  presented

# %%
# summary stats

df.describe()
# Out:
#              Account   Quantity          Price
# count      17.000000  17.000000      17.000000
# mean   462254.235294   1.764706   30705.882353
# std    259093.442862   1.032558   28444.605609
# min    141962.000000   1.000000    5000.000000
# 25%    218895.000000   1.000000    7000.000000
# 50%    412290.000000   2.000000   30000.000000
# 75%    714466.000000   2.000000   40000.000000
# max    740150.000000   5.000000  100000.000000

# %%
# select a single column

df['Account']
# Out:
# 0     714466
# 1     714466
# 2     714466
# 3     737550
# 4     146832
# 5     218895
# 6     218895
# 7     412290
# 8     740150
# 9     141962
# 10    163416
# 11    239344
# 12    239344
# 13    307599
# 14    688981
# 15    729833
# 16    729833
# Name: Account, dtype: int64

# %%
# slice certain rows 

df[0:3]
# Out:
#    Account             Name           Rep       Manager      Product  \
# 0   714466  Trantow-Barrows  Craig Booker  Debra Henley          CPU
# 1   714466  Trantow-Barrows  Craig Booker  Debra Henley     Software
# 2   714466  Trantow-Barrows  Craig Booker  Debra Henley  Maintenance
#
#    Quantity  Price     Status
# 0         1  30000  presented
# 1         1  10000  presented
# 2         2   5000    pending

# %%
# slice for rows 9-14

df[9:15]
# Out:
#     Account                         Name          Rep        Manager  \
# 9    141962                   Herman LLC  Cedric Moss  Fred Anderson
# 10   163416                  Purdy-Kunde  Cedric Moss  Fred Anderson
# 11   239344                   Stokes LLC  Cedric Moss  Fred Anderson
# 12   239344                   Stokes LLC  Cedric Moss  Fred Anderson
# 13   307599  Kassulke, Ondricka and Metz   Wendy Yule  Fred Anderson
# 14   688981                  Keeling LLC   Wendy Yule  Fred Anderson
#
#         Product  Quantity   Price     Status
# 9           CPU         2   65000        won
# 10          CPU         1   30000  presented
# 11  Maintenance         1    5000    pending
# 12     Software         1   10000  presented
# 13  Maintenance         3    7000        won
# 14          CPU         5  100000        won

# %%
# slice some rows

df.iloc[1:3, :]
# Out:
#    Account             Name           Rep       Manager      Product  \
# 1   714466  Trantow-Barrows  Craig Booker  Debra Henley     Software
# 2   714466  Trantow-Barrows  Craig Booker  Debra Henley  Maintenance
#
#    Quantity  Price     Status
# 1         1  10000  presented
# 2         2   5000    pending

# %%
# slice some columns

df.iloc[:,1:3]
# Out:
#                             Name            Rep
# 0                Trantow-Barrows   Craig Booker
# 1                Trantow-Barrows   Craig Booker
# 2                Trantow-Barrows   Craig Booker
# 3   Fritsch, Russel and Anderson   Craig Booker
# 4                   Kiehn-Spinka  Daniel Hilton
# 5                      Kulas Inc  Daniel Hilton
# 6                      Kulas Inc  Daniel Hilton
# 7                  Jerde-Hilpert     John Smith
# 8                     Barton LLC     John Smith
# 9                     Herman LLC    Cedric Moss
# 10                   Purdy-Kunde    Cedric Moss
# 11                    Stokes LLC    Cedric Moss
# 12                    Stokes LLC    Cedric Moss
# 13   Kassulke, Ondricka and Metz     Wendy Yule
# 14                   Keeling LLC     Wendy Yule
# 15                     Koepp Ltd     Wendy Yule
# 16                     Koepp Ltd     Wendy Yule

# %%
# slice for the 'manager' column

df.iloc[:,3:5]
# Out:
#           Manager      Product
# 0    Debra Henley          CPU
# 1    Debra Henley     Software
# 2    Debra Henley  Maintenance
# 3    Debra Henley          CPU
# 4    Debra Henley          CPU
# 5    Debra Henley          CPU
# 6    Debra Henley     Software
# 7    Debra Henley  Maintenance
# 8    Debra Henley          CPU
# 9   Fred Anderson          CPU
# 10  Fred Anderson          CPU
# 11  Fred Anderson  Maintenance
# 12  Fred Anderson     Software
# 13  Fred Anderson  Maintenance
# 14  Fred Anderson          CPU
# 15  Fred Anderson          CPU
# 16  Fred Anderson      Monitor

# %%
# select for an explicit value only

df.iloc[1,1]
# Out:
# 'Trantow-Barrows'

# %% [markdown]
# # StarWARs problem

# %%
starwarsdata = pd.read_csv('starWars.csv')

# %%
starwarsdata.head()
#I wanted to print the first 5 data sets.
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
# ...

# %%
starwarsdata.tail()
#I wanted to print the last 5 data sets in the dataframe.
# Out:
#       RespondentID  \
# 1182  3.288389e+09
# 1183  3.288379e+09
# 1184  3.288375e+09
# 1185  3.288373e+09
# 1186  3.288373e+09
#
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 1182                                                Yes
# 1183                                                Yes
# 1184                                                 No
# 1185                                                Yes
# 1186                                                Yes
#
#      Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1182                                                Yes
# 1183                                                Yes
# 1184                                                NaN
# 1185                                                Yes
# 1186                                                 No
#
#      Which of the following Star Wars films have you seen? Please select all that apply.  \
# ...

# %%
starwarsdata.describe()
#I wanted to know the different statistical elements of the entire table.
# Out:
#        RespondentID
# count  1.186000e+03
# mean   3.290128e+09
# std    1.055639e+06
# min    3.288373e+09
# 25%    3.289451e+09
# 50%    3.290147e+09
# 75%    3.290814e+09
# max    3.292880e+09

# %%
starwarsdata[5:20]
# Out:
#     RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 5   3.292731e+09                                                Yes
# 6   3.292719e+09                                                Yes
# 7   3.292685e+09                                                Yes
# 8   3.292664e+09                                                Yes
# 9   3.292654e+09                                                Yes
# 10  3.292640e+09                                                Yes
# 11  3.292638e+09                                                Yes
# 12  3.292635e+09                                                 No
# 13  3.292609e+09                                                Yes
# 14  3.292597e+09                                                Yes
# 15  3.292587e+09                                                Yes
# 16  3.292583e+09                                                Yes
# 17  3.292581e+09                                                Yes
# ...

# %%
starwarsdata['Have you seen any of the 6 films in the Star Wars franchise?']
#I wanted to print a single column.
# Out:
# 0       Response
# 1            Yes
# 2             No
# 3            Yes
# 4            Yes
# 5            Yes
# 6            Yes
# 7            Yes
# 8            Yes
# 9            Yes
# 10           Yes
# 11           Yes
# 12            No
# 13           Yes
# 14           Yes
# 15           Yes
# 16           Yes
# 17           Yes
# 18           Yes
# 19           Yes
# 20           Yes
# 21           Yes
# 22           Yes
# 23           Yes
# 24           Yes
# 25           Yes
# 26            No
# 27           Yes
# 28           Yes
# 29           Yes
#           ...
# 1157         Yes
# 1158          No
# 1159         Yes
# 1160          No
# 1161         Yes
# 1162         Yes
# 1163         Yes
# 1164         Yes
# 1165         Yes
# 1166         Yes
# 1167         Yes
# 1168         Yes
# 1169          No
# 1170         Yes
# 1171          No
# 1172         Yes
# 1173         Yes
# 1174         Yes
# 1175         Yes
# 1176         Yes
# 1177         Yes
# ...

# %%
starwarsdata[45:60]
#I wanted to print all the data from rows, 45 to 59.
# Out:
#     RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 45  3.292214e+09                                                Yes
# 46  3.292211e+09                                                Yes
# 47  3.292202e+09                                                 No
# 48  3.292190e+09                                                Yes
# 49  3.292187e+09                                                Yes
# 50  3.292187e+09                                                 No
# 51  3.292178e+09                                                Yes
# 52  3.292177e+09                                                Yes
# 53  3.292174e+09                                                Yes
# 54  3.292167e+09                                                Yes
# 55  3.292162e+09                                                Yes
# 56  3.292161e+09                                                 No
# 57  3.292157e+09                                                Yes
# ...

# %%
starwarsdata.iloc[[3,7]]
#I wanted to only print the data from row 3 and row 7.
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 3  3.292765e+09                                                Yes
# 7  3.292685e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 3                                                 No
# 7                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 3           Star Wars: Episode I  The Phantom Menace
# 7           Star Wars: Episode I  The Phantom Menace
#
#                                     Unnamed: 4  \
# 3  Star Wars: Episode II  Attack of the Clones
# 7  Star Wars: Episode II  Attack of the Clones
#
#                                     Unnamed: 5  \
# 3  Star Wars: Episode III  Revenge of the Sith
# 7  Star Wars: Episode III  Revenge of the Sith
#
#                           Unnamed: 6  \
# 3                                NaN
# ...

# %%
starwarsdata.iloc[:, 4:8]
#I wanted to have the entire data of columns 4 through 8 of the entire data frame.
# Out:
#                                        Unnamed: 4  \
# 0     Star Wars: Episode II  Attack of the Clones
# 1     Star Wars: Episode II  Attack of the Clones
# 2                                             NaN
# 3     Star Wars: Episode II  Attack of the Clones
# 4     Star Wars: Episode II  Attack of the Clones
# 5     Star Wars: Episode II  Attack of the Clones
# 6     Star Wars: Episode II  Attack of the Clones
# 7     Star Wars: Episode II  Attack of the Clones
# 8     Star Wars: Episode II  Attack of the Clones
# 9     Star Wars: Episode II  Attack of the Clones
# 10    Star Wars: Episode II  Attack of the Clones
# 11                                            NaN
# 12                                            NaN
# 13    Star Wars: Episode II  Attack of the Clones
# 14    Star Wars: Episode II  Attack of the Clones
# 15    Star Wars: Episode II  Attack of the Clones
# 16    Star Wars: Episode II  Attack of the Clones
# 17                                            NaN
# ...

# %%
starwarsdata.iloc[4:8,:]
#I wanted to only print the data from rows 4 through 7 in the data frame, but all the information.
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 4  3.292763e+09                                                Yes
# 5  3.292731e+09                                                Yes
# 6  3.292719e+09                                                Yes
# 7  3.292685e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 4                                                Yes
# 5                                                Yes
# 6                                                Yes
# 7                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 4           Star Wars: Episode I  The Phantom Menace
# 5           Star Wars: Episode I  The Phantom Menace
# 6           Star Wars: Episode I  The Phantom Menace
# 7           Star Wars: Episode I  The Phantom Menace
#
# ...

# %%
starwarsdata['Do you consider yourself to be a fan of the Star Trek franchise?'] = starwarsdata['Do you consider yourself to be a fan of the Star Trek franchise?'].astype(bool)
#I want to change the data type to another data type.

# %%
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#         ...
# 1157    True
# 1158    True
# 1159    True
# 1160    True
# 1161    True
# 1162    True
# 1163    True
# 1164    True
# 1165    True
# 1166    True
# 1167    True
# 1168    True
# 1169    True
# 1170    True
# 1171    True
# 1172    True
# 1173    True
# 1174    True
# 1175    True
# 1176    True
# 1177    True
# 1178    True
# 1179    True
# 1180    True
# 1181    True
# 1182    True
# 1183    True
# 1184    True
# 1185    True
# 1186    True
# Name: Do you consider yourself to be a fan of the Star Trek franchise?, dtype: bool

# %%
dummy_ranks = starwarsdata.get_dummies(starwars['prestige'], prefix='prestige')
print dummy_ranks.head()

# %% [markdown]
# # More practice from Week 1, day 1

# %%
s = pd.Series(range(-3,4))

# %%
s.dtypes
# Out:
# dtype('int64')

# %%
s
# Out:
# 0   -3
# 1   -2
# 2   -1
# 3    0
# 4    1
# 5    2
# 6    3
# dtype: int64

# %%
s<0
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
s[(s< -1) | (s>.5)]
# Out:
# 0   -3
# 1   -2
# 4    1
# 5    2
# 6    3
# dtype: int64

# %%
s[~(s<0)]
# Out:
# 3    0
# 4    1
# 5    2
# 6    3
# dtype: int64
